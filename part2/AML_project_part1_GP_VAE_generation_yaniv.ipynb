# %% [markdown]
# # Reproduce GP-VAE
# ## Instructions for use:
# 1. Clone our GP-VAE repo (**Add link here**) to your google drive
# 2. Place this notebook in your google drive
# 3. Update the ROOT_PATH to the repo folder in your g drive
# 4. **Only for the first time you run on a colab host**: perform initial installations and fixes:
#   * Un-Comment code cell 2
#   * Execute code cells 1, 2
#   * Comment cell 2 back
#   * Restart the host
# 5. Run the notebook
#
# **Note**: The train / test outputs (model, results) will be copied into the repository clone under 'model' folder in the end, as intended by the original writers.

# %%
import time
from pathlib import Path
from google.colab import drive

# Google Drive linkage
drive.mount('/content/drive')
DRIVE_ROOT_DIR = Path('/content/drive/MyDrive/colab_data/aml_project/gp_vae_for_data_generation')

# Relative paths - correct both for drive and for local (Colab) VM
datetime = time.strftime("%Y%m%d-%H%M%S")
OUTPUTS_DIR = Path(f'outputs/{datetime}')
DRIVE_OUTPUTS_DIR = DRIVE_ROOT_DIR / OUTPUTS_DIR

# Create output folders on local (Colab) VM
Path(OUTPUTS_DIR).mkdir(parents=True, exist_ok=True)
print(f'OUTPUTS_DIR = {OUTPUTS_DIR}, exists = {Path.exists(OUTPUTS_DIR)}')

Path(DRIVE_OUTPUTS_DIR).mkdir(parents=True, exist_ok=True)
print(f'DRIVE_OUTPUTS_DIR = {DRIVE_OUTPUTS_DIR}, exists = {Path.exists(DRIVE_OUTPUTS_DIR)}')

# copy code to colab host
# !cp -R $DRIVE_ROOT_DIR/* .
# !ls -la $ROOT_DIR
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# OUTPUTS_DIR = outputs/20220814-172257, exists = True
# DRIVE_OUTPUTS_DIR = /content/drive/MyDrive/colab_data/aml_project/gp_vae_for_data_generation/outputs/20220814-172257, exists = True
# total 100
# drwxr-xr-x 1 root root  4096 Aug 14 16:08 .
# drwxr-xr-x 1 root root  4096 Aug 14 16:01 ..
# drwxr-xr-x 4 root root  4096 Aug  3 20:20 .config
# drwx------ 3 root root  4096 Aug 14 16:08 data
# drwx------ 5 root root  4096 Aug 14 16:07 drive
# drwx------ 2 root root  4096 Aug 14 16:07 figures
# -rw------- 1 root root 11958 Aug 14 17:22 generate.py
# drwx------ 3 root root  4096 Aug 14 16:07 lib
# -rw------- 1 root root  1087 Aug 14 17:22 LICENSE
# drwxr-xr-x 8 root root  4096 Aug 14 17:22 outputs
# drwx------ 2 root root  4096 Aug 14 17:22 __pycache__
# -rw------- 1 root root  2364 Aug 14 17:22 README.md
# -rw------- 1 root root   146 Aug 14 17:22 requirements.txt
# drwxr-xr-x 1 root root  4096 Aug  3 20:21 sample_data
# -rw------- 1 root root 28587 Aug 14 17:22 train.py
# drwx------ 2 root root  4096 Aug 14 16:08 utils
# -rw------- 1 root root  1660 Aug 14 17:22 utils.py

# %% [markdown]
# ### Run the below cell only once per new host in Colab, then comment it out.

# %%
# /# Run this cell once for a new host, then comment this cell, restart the host, and rerun all
# #---------------------------------------------------------------------------------
# # Update data download scripts
# !sudo apt-get install dos2unix
# !dos2unix data/*.sh
# !chmod +x data/*.sh
# !ls -la data

# # reinstall old packages for old code
# !pip install -r requirements.txt

# # Download dataset for hmnist
# !data/load_hmnist.sh

# %% [markdown]
# ## Train model

# %%
#Train on limited dataset
SAMPLES_PER_DIGIT = 400
NUM_EPOCHS = 20

# !python train.py --model_type gp-vae --data_type hmnist --exp_name reproduce_hmnist --seed 111 --testing --banded_covar --latent_dim 256 --encoder_sizes=256,256 --decoder_sizes=256,256,256 --window_size 3 --sigma 1 --length_scale 2 --beta 0.8 --num_epochs $NUM_EPOCHS  --train_class_number $SAMPLES_PER_DIGIT --base_dir $OUTPUTS_DIR --black_flip_ratio 0.7 --white_flip_ratio 0.6
# Out:
# Testing:  True 	 Seed: 111
# Full exp name:  outputs/20220814-172257/model
# tcmalloc: large alloc 1881604096 bytes == 0x6602000 @  0x7fcf07d441e7 0x7fcf04799cf1 0x7fcf047fe7c8 0x7fcf0479d4f1 0x5947d6 0x548cc1 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x4bc98a 0x533274 0x4d3969 0x512147 0x549e0e 0x593fce 0x5118f8 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e
# tcmalloc: large alloc 1881604096 bytes == 0x768b2000 @  0x7fcf07d441e7 0x7fcf04799cf1 0x7fcf047fe7c8 0x7fcf0479d4f1 0x5947d6 0x548cc1 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x4bc98a 0x533274 0x4d3969 0x512147 0x549e0e 0x593fce 0x5118f8 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e
# tcmalloc: large alloc 1881604096 bytes == 0xe6b22000 @  0x7fcf07d441e7 0x7fcf04799cf1 0x7fcf047fe7c8 0x7fcf0479d4f1 0x5947d6 0x548cc1 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x4bc98a 0x533274 0x4d3969 0x512147 0x549e0e 0x593fce 0x5118f8 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e
# 4000
# 2022-08-14 17:23:31.591201: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-08-14 17:23:31.721642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:31.722270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-14 17:23:31.729137: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-14 17:23:31.998736: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-14 17:23:32.062033: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-14 17:23:32.080158: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-14 17:23:32.250766: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-14 17:23:32.347954: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-14 17:23:32.672053: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-14 17:23:32.672275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:32.672939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:32.673462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-14 17:23:32.678607: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-08-14 17:23:32.735770: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2022-08-14 17:23:32.747073: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x216ea00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-08-14 17:23:32.747111: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-08-14 17:23:33.033810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:33.036595: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x216e840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-08-14 17:23:33.036632: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2022-08-14 17:23:33.036911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:33.037492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-14 17:23:33.037569: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-14 17:23:33.037591: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-14 17:23:33.037612: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-14 17:23:33.037632: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-14 17:23:33.037656: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-14 17:23:33.037675: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-14 17:23:33.037707: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-14 17:23:33.037810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:33.038385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:33.038888: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-14 17:23:33.042476: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-14 17:23:33.043822: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-14 17:23:33.043856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-08-14 17:23:33.043869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-08-14 17:23:33.049408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:33.050005: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:33.052857: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-14 17:23:33.052913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0814 17:23:37.018750 140527170701184 deprecation.py:323] From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/util/random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2022-08-14 17:23:37.037197: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 313600000 exceeds 10% of system memory.
# 2022-08-14 17:23:37.194792: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 627200000 exceeds 10% of system memory.
# Using CNN preprocessor
# 2022-08-14 17:23:37.454789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:37.455435: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-14 17:23:37.455523: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-14 17:23:37.455549: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-14 17:23:37.455596: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-14 17:23:37.455622: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-14 17:23:37.455646: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-14 17:23:37.455676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-14 17:23:37.455703: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-14 17:23:37.455795: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:37.456452: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:37.457027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-14 17:23:37.457070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-14 17:23:37.457087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-08-14 17:23:37.457098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-08-14 17:23:37.457205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:37.457837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:23:37.458340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# GPU support:  True
# Training...
# 2022-08-14 17:23:37.524420: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x553c9ad0
# 2022-08-14 17:23:37.524525: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-14 17:23:38.559095: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-14 17:23:39.271942: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-14 17:23:46.499886: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              multiple                  602368
# _________________________________________________________________
# dense (Dense)                multiple                  65792
# _________________________________________________________________
# dense_1 (Dense)              multiple                  197376
# =================================================================
# Total params: 865,536
# Trainable params: 865,536
# Non-trainable params: 0
# _________________________________________________________________
# Encoder:  None
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_3 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_4 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_5 (Dense)              multiple                  201488
# =================================================================
# Total params: 398,864
# Trainable params: 398,864
# Non-trainable params: 0
# _________________________________________________________________
# Decoder:  None
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              multiple                  2560
# _________________________________________________________________
# conv2d_1 (Conv2D)            multiple                  2305
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# Preprocessor:  None
# W0814 17:23:46.776853 140527170701184 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# 2022-08-14 17:23:47.901264: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 125440000 exceeds 10% of system memory.
# 2022-08-14 17:23:47.990366: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 250880000 exceeds 10% of system memory.
# ================================================
# Learning rate: 0.001 | Global gradient norm: 558.48
# Step 0) Time = 2.411988
# Train loss = 8864.035 | NLL = 3818.851 | KL = 6306.479
# Validation loss = 8939.993 | NLL = 3890.196 | KL = 6312.246
# ================================================
# Learning rate: 0.001 | Global gradient norm: 611.60
# Step 62) Time = 55.188641
# Train loss = 1780.133 | NLL = 739.539 | KL = 1300.742
# Validation loss = 1697.102 | NLL = 656.738 | KL = 1300.455
# ================================================
# Learning rate: 0.001 | Global gradient norm: 650.18
# Step 124) Time = 53.522262
# Train loss = 1747.259 | NLL = 722.100 | KL = 1281.449
# Validation loss = 1667.776 | NLL = 641.776 | KL = 1282.500
# ================================================
# Learning rate: 0.001 | Global gradient norm: 244.69
# Step 186) Time = 52.339691
# Train loss = 1693.919 | NLL = 673.116 | KL = 1276.004
# Validation loss = 1640.155 | NLL = 619.269 | KL = 1276.107
# ================================================
# Learning rate: 0.001 | Global gradient norm: 918.96
# Step 248) Time = 52.557821
# Train loss = 1676.097 | NLL = 657.941 | KL = 1272.695
# Validation loss = 1659.362 | NLL = 640.686 | KL = 1273.344
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1861.80
# Step 310) Time = 55.264465
# Train loss = 1674.062 | NLL = 655.584 | KL = 1273.098
# Validation loss = 1630.350 | NLL = 612.123 | KL = 1272.783
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1119.40
# Step 372) Time = 53.417731
# Train loss = 1629.143 | NLL = 606.564 | KL = 1278.223
# Validation loss = 1611.130 | NLL = 588.394 | KL = 1278.421
# ================================================
# Learning rate: 0.001 | Global gradient norm: 358.53
# Step 434) Time = 52.647061
# Train loss = 1615.418 | NLL = 591.053 | KL = 1280.456
# Validation loss = 1601.854 | NLL = 577.122 | KL = 1280.914
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1069.50
# Step 496) Time = 53.071611
# Train loss = 1571.354 | NLL = 545.796 | KL = 1281.948
# Validation loss = 1585.968 | NLL = 560.903 | KL = 1281.332
# ================================================
# Learning rate: 0.001 | Global gradient norm: 376.12
# Step 558) Time = 52.792195
# Train loss = 1570.994 | NLL = 544.099 | KL = 1283.619
# Validation loss = 1579.646 | NLL = 553.197 | KL = 1283.061
# ================================================
# Learning rate: 0.001 | Global gradient norm: 2552.22
# Step 620) Time = 53.401185
# Train loss = 1558.946 | NLL = 527.794 | KL = 1288.939
# Validation loss = 1532.828 | NLL = 501.738 | KL = 1288.863
# ================================================
# Learning rate: 0.001 | Global gradient norm: 324.40
# Step 682) Time = 52.290201
# Train loss = 1524.997 | NLL = 489.931 | KL = 1293.832
# Validation loss = 1527.214 | NLL = 493.236 | KL = 1292.473
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1047.63
# Step 744) Time = 52.306786
# Train loss = 1551.460 | NLL = 515.721 | KL = 1294.674
# Validation loss = 1517.233 | NLL = 480.598 | KL = 1295.794
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1203.97
# Step 806) Time = 53.755311
# Train loss = 1497.788 | NLL = 460.815 | KL = 1296.217
# Validation loss = 1504.260 | NLL = 466.295 | KL = 1297.456
# ================================================
# Learning rate: 0.001 | Global gradient norm: 2054.71
# Step 868) Time = 53.498348
# Train loss = 1491.805 | NLL = 454.592 | KL = 1296.516
# Validation loss = 1482.755 | NLL = 445.040 | KL = 1297.143
# ================================================
# Learning rate: 0.001 | Global gradient norm: 617.28
# Step 930) Time = 54.142289
# Train loss = 1478.607 | NLL = 438.221 | KL = 1300.482
# Validation loss = 1467.438 | NLL = 427.130 | KL = 1300.384
# ================================================
# Learning rate: 0.001 | Global gradient norm: 2367.49
# Step 992) Time = 53.708538
# Train loss = 1494.064 | NLL = 453.012 | KL = 1301.315
# Validation loss = 1472.887 | NLL = 433.169 | KL = 1299.646
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1881.55
# Step 1054) Time = 54.992415
# Train loss = 1478.636 | NLL = 436.535 | KL = 1302.626
# Validation loss = 1470.925 | NLL = 430.718 | KL = 1300.259
# ================================================
# Learning rate: 0.001 | Global gradient norm: 254.30
# Step 1116) Time = 53.107284
# Train loss = 1474.936 | NLL = 430.468 | KL = 1305.584
# Validation loss = 1466.619 | NLL = 424.043 | KL = 1303.220
# ================================================
# Learning rate: 0.001 | Global gradient norm: 2465.99
# Step 1178) Time = 54.658398
# Train loss = 1476.343 | NLL = 432.293 | KL = 1305.062
# Validation loss = 1453.216 | NLL = 411.112 | KL = 1302.629
# ================================================
# Learning rate: 0.001 | Global gradient norm: 3396.62
# Step 1240) Time = 52.978239
# Train loss = 1452.767 | NLL = 410.519 | KL = 1302.810
# Validation loss = 1453.227 | NLL = 412.111 | KL = 1301.395
# Evaluation...
# NLL miss: 0.6571
# MSE miss: 0.2646
# AUROC: 0.9560
# AUPRC: 0.7926
# Training finished.

# %%
# Copy trained models back to drive
# !cp -R $OUTPUTS_DIR/* $DRIVE_OUTPUTS_DIR
print(f'DRIVE_OUTPUTS_DIR = {DRIVE_OUTPUTS_DIR}')
# !ls -la $DRIVE_OUTPUTS_DIR
# Out:
# DRIVE_OUTPUTS_DIR = /content/drive/MyDrive/colab_data/aml_project/gp_vae_for_data_generation/outputs/20220814-172257
# total 122505
# -rw------- 1 root root 125440128 Aug 14 17:44 base_data.npy
# drwx------ 2 root root      4096 Aug 14 17:44 model
# DRIVE_OUTPUTS_DIR = /content/drive/MyDrive/colab_data/aml_project/gp_vae_for_data_generation/outputs/20220814-172257
# total 122505
# -rw------- 1 root root 125440128 Aug 14 17:44 base_data.npy
# drwx------ 2 root root      4096 Aug 14 17:44 model

# %% [markdown]
# ## Generate new samples based on the dataset used in train and the model

# %%
# copy code to colab host
# !cp -R $DRIVE_ROOT_DIR/* .

# %%
#Train on limited dataset

# !python generate.py --model_type gp-vae --data_type hmnist --exp_name reproduce_hmnist --seed 123 --testing --banded_covar --latent_dim 256 --encoder_sizes=256,256 --decoder_sizes=256,256,256 --window_size 3 --sigma 1 --length_scale 2 --beta 0.8 --num_epochs 20 --base_dir $OUTPUTS_DIR --black_flip_ratio 0.7 --white_flip_ratio 0.6
# Out:
# Testing:  True 	 Seed: 123
# GENERATED_DATA_PATH = outputs/20220814-172257/generated_data, exists = True
# Using CNN preprocessor
# 2022-08-14 17:44:49.796118: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-08-14 17:44:49.865405: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:49.866060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-14 17:44:49.872357: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-14 17:44:49.895855: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-14 17:44:49.898616: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-14 17:44:49.899085: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-14 17:44:49.991263: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-14 17:44:50.025522: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-14 17:44:50.110833: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-14 17:44:50.111044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.111741: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.112386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-14 17:44:50.112779: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-08-14 17:44:50.117289: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2022-08-14 17:44:50.120175: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1bd8a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-08-14 17:44:50.120218: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-08-14 17:44:50.355166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.356834: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1bd8840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-08-14 17:44:50.356869: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2022-08-14 17:44:50.357059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.357579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-14 17:44:50.357645: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-14 17:44:50.357666: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-14 17:44:50.357693: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-14 17:44:50.357712: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-14 17:44:50.357731: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-14 17:44:50.357750: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-14 17:44:50.357769: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-14 17:44:50.357859: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.358410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.358965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-14 17:44:50.359041: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-14 17:44:50.360305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-14 17:44:50.360338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-08-14 17:44:50.360352: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-08-14 17:44:50.360558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.361439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-14 17:44:50.361999: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-14 17:44:50.362040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2022-08-14 17:44:52.967386: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x24473ac8
# 2022-08-14 17:44:52.967640: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-14 17:44:54.209273: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-14 17:44:54.939982: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-14 17:44:58.003064: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# W0814 17:44:58.192376 139710928041856 deprecation.py:323] From /content/lib/models.py:119: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              multiple                  602368
# _________________________________________________________________
# dense (Dense)                multiple                  65792
# _________________________________________________________________
# dense_1 (Dense)              multiple                  197376
# =================================================================
# Total params: 865,536
# Trainable params: 865,536
# Non-trainable params: 0
# _________________________________________________________________
# Encoder:  None
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_3 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_4 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_5 (Dense)              multiple                  201488
# =================================================================
# Total params: 398,864
# Trainable params: 398,864
# Non-trainable params: 0
# _________________________________________________________________
# Decoder:  None
# Generating...
# Generation finished.

# %%
# Copy trained models back to drive
# !cp -R $OUTPUTS_DIR/generated_data $DRIVE_OUTPUTS_DIR
print(f'DRIVE_OUTPUTS_DIR = {DRIVE_OUTPUTS_DIR}')
# !ls -la $DRIVE_OUTPUTS_DIR/generated_data
# Out:
# DRIVE_OUTPUTS_DIR = /content/drive/MyDrive/colab_data/aml_project/gp_vae_for_data_generation/outputs/20220814-172257
# total 285039
# -rw------- 1 root root     38336 Aug 14 17:45 hmnist_reconstruction.pdf
# -rw------- 1 root root 125440128 Aug 14 17:45 imputed_no_gt.npy
# -rw------- 1 root root 125440128 Aug 14 17:45 imputed.npy
# -rw------- 1 root root  40960128 Aug 14 17:45 z_mean.npy
