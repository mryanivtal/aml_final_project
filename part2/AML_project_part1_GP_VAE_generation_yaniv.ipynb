# %% [markdown]
# # Reproduce GP-VAE
# ## Instructions for use:
# 1. Clone our GP-VAE repo (**Add link here**) to your google drive
# 2. Place this notebook in your google drive
# 3. Update the ROOT_PATH to the repo folder in your g drive
# 4. **Only for the first time you run on a colab host**: perform initial installations and fixes:
#   * Un-Comment code cell 2
#   * Execute code cells 1, 2
#   * Comment cell 2 back
#   * Restart the host
# 5. Run the notebook
#
# **Note**: The train / test outputs (model, results) will be copied into the repository clone under 'model' folder in the end, as intended by the original writers.

# %%
import time
from pathlib import Path
from google.colab import drive

# Google Drive linkage
drive.mount('/content/drive')
DRIVE_ROOT_DIR = Path('/content/drive/MyDrive/colab_data/aml_project/gp_vae_for_data_generation')

# Relative paths - correct both for drive and for local (Colab) VM
datetime = time.strftime("%Y%m%d-%H%M%S")
OUTPUTS_DIR = Path(f'outputs/{datetime}')
DRIVE_OUTPUTS_DIR = DRIVE_ROOT_DIR / OUTPUTS_DIR

# Create output folders on local (Colab) VM
Path(OUTPUTS_DIR).mkdir(parents=True, exist_ok=True)
print(f'OUTPUTS_DIR = {OUTPUTS_DIR}, exists = {Path.exists(OUTPUTS_DIR)}')

Path(DRIVE_OUTPUTS_DIR).mkdir(parents=True, exist_ok=True)
print(f'DRIVE_OUTPUTS_DIR = {DRIVE_OUTPUTS_DIR}, exists = {Path.exists(DRIVE_OUTPUTS_DIR)}')

# !ls -la $ROOT_DIR
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# MODELS_DIR = outputs/20220812-120620/models, exists = True
# DATA_FOR_TRAIN_AND_GENERATION = outputs/20220812-120620/base_data_for_train_and_generation, exists = True
# DATA_FOR_TRAIN_AND_GENERATION = outputs/20220812-120620/generated_data, exists = True
# total 108
# drwxr-xr-x 1 root root  4096 Aug 12 12:02 .
# drwxr-xr-x 1 root root  4096 Aug 12 11:56 ..
# drwxr-xr-x 4 root root  4096 Aug  3 20:20 .config
# drwx------ 3 root root  4096 Aug 12 12:02 data
# drwx------ 5 root root  4096 Aug 12 12:01 drive
# drwx------ 2 root root  4096 Aug 12 12:01 figures
# drwx------ 2 root root  4096 Aug 12 12:01 generated_data
# -rw------- 1 root root 11757 Aug 12 12:01 generate.py
# drwx------ 3 root root  4096 Aug 12 12:01 lib
# -rw------- 1 root root  1087 Aug 12 12:01 LICENSE
# drwx------ 4 root root  4096 Aug 12 12:01 models
# drwxr-xr-x 4 root root  4096 Aug 12 12:06 outputs
# drwx------ 2 root root  4096 Aug 12 12:02 __pycache__
# -rw------- 1 root root  2364 Aug 12 12:02 README.md
# -rw------- 1 root root   146 Aug 12 12:02 requirements.txt
# drwxr-xr-x 1 root root  4096 Aug  3 20:21 sample_data
# -rw------- 1 root root 25353 Aug 12 12:02 train.py
# drwx------ 2 root root  4096 Aug 12 12:02 utils
# -rw------- 1 root root   614 Aug 12 12:02 utils.py

# %% [markdown]
# ### Run the below cell only once per new host in Colab, then comment it out.

# %%
# # Run this cell once for a new host, then comment this cell, restart the host, and rerun all
# #---------------------------------------------------------------------------------

# # copy code to colab host
# !cp -R $DRIVE_ROOT_DIR/* .

# # Update data download scripts
# !sudo apt-get install dos2unix
# !dos2unix data/*.sh
# !chmod +x data/*.sh
# !ls -la data

# # reinstall old packages for old code
# !pip install -r requirements.txt

# # Download dataset for hmnist
# !data/load_hmnist.sh

# %% [markdown]
# ## Train model

# %%
#Train on limited dataset
SAMPLES_PER_DIGIT = 500
# !python train.py --model_type gp-vae --data_type hmnist --exp_name reproduce_hmnist --seed 111 --testing --banded_covar --latent_dim 256 --encoder_sizes=256,256 --decoder_sizes=256,256,256 --window_size 3 --sigma 1 --length_scale 2 --beta 0.8 --num_epochs 20  --train_class_number $SAMPLES_PER_DIGIT --base_dir $OUTPUTS_DIR
# Out:
# Testing:  True 	 Seed: 111
# Full exp name:  outputs/20220812-120620/reproduce_hmnist
# tcmalloc: large alloc 1881604096 bytes == 0x6318000 @  0x7f207756d1e7 0x7f2074002cf1 0x7f20740677c8 0x7f20740064f1 0x5947d6 0x548cc1 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x4bc98a 0x533274 0x4d3969 0x512147 0x549e0e 0x593fce 0x5118f8 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e
# tcmalloc: large alloc 1881604096 bytes == 0x765cc000 @  0x7f207756d1e7 0x7f2074002cf1 0x7f20740677c8 0x7f20740064f1 0x5947d6 0x548cc1 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x4bc98a 0x533274 0x4d3969 0x512147 0x549e0e 0x593fce 0x5118f8 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e
# tcmalloc: large alloc 1881604096 bytes == 0xe683c000 @  0x7f207756d1e7 0x7f2074002cf1 0x7f20740677c8 0x7f20740064f1 0x5947d6 0x548cc1 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x4bc98a 0x533274 0x4d3969 0x512147 0x549e0e 0x593fce 0x5118f8 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e
# 5000
# (5000, 10, 784)
# 2022-08-12 12:07:14.368161: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-08-12 12:07:14.457655: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:14.458294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-12 12:07:14.481074: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 12:07:14.640983: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 12:07:14.713083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-12 12:07:14.732673: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-12 12:07:14.915281: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 12:07:15.025998: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-12 12:07:15.360722: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 12:07:15.360919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.361623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.362143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-12 12:07:15.394919: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-08-12 12:07:15.490845: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-08-12 12:07:15.504501: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e88a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-08-12 12:07:15.504548: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-08-12 12:07:15.893489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.902709: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e88840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-08-12 12:07:15.902750: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2022-08-12 12:07:15.902998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.903575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-12 12:07:15.903651: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 12:07:15.903672: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 12:07:15.903692: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-12 12:07:15.903711: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-12 12:07:15.903730: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 12:07:15.903750: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-12 12:07:15.903769: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 12:07:15.903842: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.904423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.904925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-12 12:07:15.914453: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 12:07:15.915953: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-12 12:07:15.916000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-08-12 12:07:15.916029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-08-12 12:07:15.923676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.927088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:15.927779: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-12 12:07:15.927853: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# W0812 12:07:21.265884 139777422251904 deprecation.py:323] From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/util/random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2022-08-12 12:07:21.294384: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 313600000 exceeds 10% of system memory.
# 2022-08-12 12:07:21.444854: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 313600000 exceeds 10% of system memory.
# Using CNN preprocessor
# 2022-08-12 12:07:21.701278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:21.701862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-12 12:07:21.701945: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 12:07:21.701968: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 12:07:21.701995: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-12 12:07:21.702016: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-12 12:07:21.702037: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 12:07:21.702059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-12 12:07:21.702081: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 12:07:21.702180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:21.702830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:21.703423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-12 12:07:21.703476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-12 12:07:21.703507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-08-12 12:07:21.703518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-08-12 12:07:21.703613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:21.704160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 12:07:21.704667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# GPU support:  True
# Training...
# 2022-08-12 12:07:21.788076: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x193d5ac0
# 2022-08-12 12:07:21.790156: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 12:07:23.141779: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 12:07:23.898254: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 12:07:27.269671: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              multiple                  602368
# _________________________________________________________________
# dense (Dense)                multiple                  65792
# _________________________________________________________________
# dense_1 (Dense)              multiple                  197376
# =================================================================
# Total params: 865,536
# Trainable params: 865,536
# Non-trainable params: 0
# _________________________________________________________________
# Encoder:  None
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_3 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_4 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_5 (Dense)              multiple                  201488
# =================================================================
# Total params: 398,864
# Trainable params: 398,864
# Non-trainable params: 0
# _________________________________________________________________
# Decoder:  None
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              multiple                  2560
# _________________________________________________________________
# conv2d_1 (Conv2D)            multiple                  2305
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# Preprocessor:  None
# W0812 12:07:27.551585 139777422251904 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# 2022-08-12 12:07:28.847738: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 156800000 exceeds 10% of system memory.
# 2022-08-12 12:07:28.945569: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 156800000 exceeds 10% of system memory.
# ================================================
# Learning rate: 0.001 | Global gradient norm: 508.95
# Step 0) Time = 2.403315
# Train loss = 7974.065 | NLL = 2908.426 | KL = 6332.050
# Validation loss = 8007.656 | NLL = 2939.461 | KL = 6335.244
# ================================================
# Learning rate: 0.001 | Global gradient norm: 180.44
# Step 78) Time = 63.094125
# Train loss = 1590.627 | NLL = 558.795 | KL = 1289.790
# Validation loss = 1634.818 | NLL = 603.267 | KL = 1289.440
# ================================================
# Learning rate: 0.001 | Global gradient norm: 137.54
# Step 156) Time = 70.603977
# Train loss = 1641.105 | NLL = 621.766 | KL = 1274.173
# Validation loss = 1600.452 | NLL = 580.821 | KL = 1274.539
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1120.75
# Step 234) Time = 62.769408
# Train loss = 1614.382 | NLL = 596.116 | KL = 1272.832
# Validation loss = 1581.910 | NLL = 563.292 | KL = 1273.273
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1027.01
# Step 312) Time = 63.038978
# Train loss = 1607.983 | NLL = 585.498 | KL = 1278.106
# Validation loss = 1594.065 | NLL = 571.652 | KL = 1278.017
# ================================================
# Learning rate: 0.001 | Global gradient norm: 659.48
# Step 390) Time = 63.201748
# Train loss = 1582.410 | NLL = 557.547 | KL = 1281.079
# Validation loss = 1532.227 | NLL = 508.089 | KL = 1280.173
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1601.51
# Step 468) Time = 66.283286
# Train loss = 1546.716 | NLL = 520.244 | KL = 1283.090
# Validation loss = 1513.619 | NLL = 488.512 | KL = 1281.383
# ================================================
# Learning rate: 0.001 | Global gradient norm: 922.51
# Step 546) Time = 65.017624
# Train loss = 1518.941 | NLL = 488.034 | KL = 1288.634
# Validation loss = 1513.539 | NLL = 483.479 | KL = 1287.575
# ================================================
# Learning rate: 0.001 | Global gradient norm: 528.79
# Step 624) Time = 64.401211
# Train loss = 1519.406 | NLL = 484.047 | KL = 1294.199
# Validation loss = 1497.923 | NLL = 465.855 | KL = 1290.086
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1347.02
# Step 702) Time = 68.977602
# Train loss = 1494.387 | NLL = 458.993 | KL = 1294.243
# Validation loss = 1481.871 | NLL = 447.070 | KL = 1293.502
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1498.79
# Step 780) Time = 72.214068
# Train loss = 1456.440 | NLL = 421.133 | KL = 1294.134
# Validation loss = 1438.441 | NLL = 402.253 | KL = 1295.234
# ================================================
# Learning rate: 0.001 | Global gradient norm: 947.70
# Step 858) Time = 70.024638
# Train loss = 1449.117 | NLL = 410.695 | KL = 1298.027
# Validation loss = 1445.802 | NLL = 406.421 | KL = 1299.227
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1537.12
# Step 936) Time = 67.856877
# Train loss = 1465.739 | NLL = 425.846 | KL = 1299.866
# Validation loss = 1436.499 | NLL = 397.324 | KL = 1298.969
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1265.42
# Step 1014) Time = 68.244256
# Train loss = 1432.177 | NLL = 388.884 | KL = 1304.117
# Validation loss = 1429.046 | NLL = 386.501 | KL = 1303.182
# ================================================
# Learning rate: 0.001 | Global gradient norm: 2398.58
# Step 1092) Time = 68.051550
# Train loss = 1447.444 | NLL = 405.835 | KL = 1302.011
# Validation loss = 1416.227 | NLL = 375.425 | KL = 1301.003
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1084.91
# Step 1170) Time = 69.343163
# Train loss = 1437.751 | NLL = 394.649 | KL = 1303.877
# Validation loss = 1401.304 | NLL = 359.544 | KL = 1302.199
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1073.21
# Step 1248) Time = 69.538183
# Train loss = 1404.164 | NLL = 359.244 | KL = 1306.149
# Validation loss = 1412.101 | NLL = 368.746 | KL = 1304.193
# ================================================
# Learning rate: 0.001 | Global gradient norm: 546.27
# Step 1326) Time = 67.734571
# Train loss = 1417.192 | NLL = 372.511 | KL = 1305.851
# Validation loss = 1401.851 | NLL = 358.492 | KL = 1304.199
# ================================================
# Learning rate: 0.001 | Global gradient norm: 339.31
# Step 1404) Time = 69.923822
# Train loss = 1424.363 | NLL = 378.852 | KL = 1306.888
# Validation loss = 1401.360 | NLL = 356.770 | KL = 1305.737
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1768.32
# Step 1482) Time = 68.903433
# Train loss = 1374.224 | NLL = 327.494 | KL = 1308.412
# Validation loss = 1384.190 | NLL = 340.017 | KL = 1305.217
# ================================================
# Learning rate: 0.001 | Global gradient norm: 1018.17
# Step 1560) Time = 69.393248
# Train loss = 1387.143 | NLL = 339.129 | KL = 1310.018
# Validation loss = 1388.369 | NLL = 342.262 | KL = 1307.634
# Evaluation...
# NLL miss: 0.3686
# MSE miss: 0.1453
# AUROC: 0.9598
# AUPRC: 0.8047
# Training finished.

# %%
# Copy trained models back to drive
# !cp -R $OUTPUTS_DIR/* $DRIVE_OUTPUTS_DIR
# !ls -la $DRIVE_OUTPUTS_DIR
# Out:
# DRIVE_OUTPUTS_DIR = /content/drive/MyDrive/colab_data/aml_project/gp_vae_for_data_generation/outputs/20220812-120620, exists = True
# total 153142
# drwx------ 2 root root      4096 Aug 12 12:52 base_data_for_train_and_generation
# -rw------- 1 root root 156800128 Aug 12 12:52 base_data.npy
# drwx------ 2 root root      4096 Aug 12 12:52 generated_data
# drwx------ 2 root root      4096 Aug 12 12:52 models
# drwx------ 2 root root      4096 Aug 12 12:52 reproduce_hmnist

# %% [markdown]
# ## Generate new samples based on the dataset used in train and the model

# %%
# copy code to colab host
# !cp -R $DRIVE_ROOT_DIR/* .

# %%
#Train on limited dataset

# !python generate.py --model_type gp-vae --data_type hmnist --exp_name reproduce_hmnist --seed 123 --testing --banded_covar --latent_dim 256 --encoder_sizes=256,256 --decoder_sizes=256,256,256 --window_size 3 --sigma 1 --length_scale 2 --beta 0.8 --num_epochs 20 --base_dir $OUTPUTS_DIR
# Out:
# Testing:  True 	 Seed: 123
# GENERATED_DATA_PATH = outputs/20220812-120620/generated_data, exists = True
# Using CNN preprocessor
# 2022-08-12 13:23:22.523645: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-08-12 13:23:22.528803: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-08-12 13:23:22.530707: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3010bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-08-12 13:23:22.530740: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-08-12 13:23:22.543174: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-08-12 13:23:22.893522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.896547: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3011d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-08-12 13:23:22.896604: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2022-08-12 13:23:22.898205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.898860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-12 13:23:22.899933: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 13:23:22.911947: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 13:23:22.918556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-12 13:23:22.920436: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-12 13:23:22.923265: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 13:23:22.928055: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-12 13:23:22.944991: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 13:23:22.945239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.945979: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.946773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-12 13:23:22.946920: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 13:23:22.948363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-12 13:23:22.948400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-08-12 13:23:22.948413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-08-12 13:23:22.948626: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.949288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.952117: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-12 13:23:22.952226: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# GPU support:  True
# 2022-08-12 13:23:22.953588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.954194: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-12 13:23:22.954268: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 13:23:22.954295: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 13:23:22.954316: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-12 13:23:22.954338: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-12 13:23:22.954358: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 13:23:22.954377: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-12 13:23:22.954397: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 13:23:22.954495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.955137: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.955681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-12 13:23:22.956252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.956832: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2022-08-12 13:23:22.956893: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-08-12 13:23:22.956916: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 13:23:22.956937: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-08-12 13:23:22.956961: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-08-12 13:23:22.956983: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 13:23:22.957002: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-08-12 13:23:22.957024: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 13:23:22.957092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.957720: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.958268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-08-12 13:23:22.958311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-08-12 13:23:22.958326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-08-12 13:23:22.958337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-08-12 13:23:22.958427: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.959010: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-12 13:23:22.959578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14257 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2022-08-12 13:23:23.515108: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x1a15da98
# 2022-08-12 13:23:23.515246: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-08-12 13:23:23.895323: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-08-12 13:23:24.190361: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-08-12 13:23:26.814242: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# W0812 13:23:27.010891 140258539853696 deprecation.py:323] From /content/lib/models.py:119: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              multiple                  602368
# _________________________________________________________________
# dense (Dense)                multiple                  65792
# _________________________________________________________________
# dense_1 (Dense)              multiple                  197376
# =================================================================
# Total params: 865,536
# Trainable params: 865,536
# Non-trainable params: 0
# _________________________________________________________________
# Encoder:  None
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_3 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_4 (Dense)              multiple                  65792
# _________________________________________________________________
# dense_5 (Dense)              multiple                  201488
# =================================================================
# Total params: 398,864
# Trainable params: 398,864
# Non-trainable params: 0
# _________________________________________________________________
# Decoder:  None
# Generating...
# Generation finished.
# W0812 13:23:37.752531 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer
# W0812 13:23:37.752760 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer_step
# W0812 13:23:37.752823 140258539853696 util.py:144] Unresolved object in checkpoint: (root).save_counter
# W0812 13:23:37.752872 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-0
# W0812 13:23:37.752921 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-1
# W0812 13:23:37.752969 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-2
# W0812 13:23:37.753015 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-3
# W0812 13:23:37.753060 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-0
# W0812 13:23:37.753132 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-1
# W0812 13:23:37.753198 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-2
# W0812 13:23:37.753250 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer.beta1_power
# W0812 13:23:37.753300 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer.beta2_power
# W0812 13:23:37.753349 140258539853696 util.py:144] Unresolved object in checkpoint: (root).preprocessor.layer-0
# W0812 13:23:37.753397 140258539853696 util.py:144] Unresolved object in checkpoint: (root).preprocessor.layer-1
# W0812 13:23:37.753446 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-0.kernel
# W0812 13:23:37.753495 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-0.bias
# W0812 13:23:37.753549 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-1.kernel
# W0812 13:23:37.753598 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-1.bias
# W0812 13:23:37.753647 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-2.kernel
# W0812 13:23:37.753696 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-2.bias
# W0812 13:23:37.753745 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-3.kernel
# W0812 13:23:37.753793 140258539853696 util.py:144] Unresolved object in checkpoint: (root).decoder.layer-3.bias
# W0812 13:23:37.753841 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-0.kernel
# W0812 13:23:37.753890 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-0.bias
# W0812 13:23:37.753937 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-1.kernel
# W0812 13:23:37.753986 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-1.bias
# W0812 13:23:37.754034 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-2.kernel
# W0812 13:23:37.754082 140258539853696 util.py:144] Unresolved object in checkpoint: (root).encoder.layer-2.bias
# W0812 13:23:37.754131 140258539853696 util.py:144] Unresolved object in checkpoint: (root).preprocessor.layer-0.kernel
# W0812 13:23:37.754189 140258539853696 util.py:144] Unresolved object in checkpoint: (root).preprocessor.layer-0.bias
# W0812 13:23:37.754238 140258539853696 util.py:144] Unresolved object in checkpoint: (root).preprocessor.layer-1.kernel
# W0812 13:23:37.754297 140258539853696 util.py:144] Unresolved object in checkpoint: (root).preprocessor.layer-1.bias
# W0812 13:23:37.754342 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-0.kernel
# W0812 13:23:37.754388 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-0.bias
# W0812 13:23:37.754433 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-1.kernel
# W0812 13:23:37.754479 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-1.bias
# W0812 13:23:37.754524 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-2.kernel
# W0812 13:23:37.754574 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-2.bias
# W0812 13:23:37.754619 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-3.kernel
# W0812 13:23:37.754664 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).decoder.layer-3.bias
# W0812 13:23:37.754709 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).encoder.layer-0.kernel
# W0812 13:23:37.754754 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).encoder.layer-0.bias
# W0812 13:23:37.754800 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).encoder.layer-1.kernel
# W0812 13:23:37.754844 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).encoder.layer-1.bias
# W0812 13:23:37.754889 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).encoder.layer-2.kernel
# W0812 13:23:37.754933 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).encoder.layer-2.bias
# W0812 13:23:37.754977 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).preprocessor.layer-0.kernel
# W0812 13:23:37.755023 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).preprocessor.layer-0.bias
# W0812 13:23:37.755071 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).preprocessor.layer-1.kernel
# W0812 13:23:37.755116 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).preprocessor.layer-1.bias
# W0812 13:23:37.755168 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-0.kernel
# W0812 13:23:37.755214 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-0.bias
# W0812 13:23:37.755259 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-1.kernel
# W0812 13:23:37.755305 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-1.bias
# W0812 13:23:37.755351 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-2.kernel
# W0812 13:23:37.755396 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-2.bias
# W0812 13:23:37.755441 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-3.kernel
# W0812 13:23:37.755486 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).decoder.layer-3.bias
# W0812 13:23:37.755531 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).encoder.layer-0.kernel
# W0812 13:23:37.755581 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).encoder.layer-0.bias
# W0812 13:23:37.755627 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).encoder.layer-1.kernel
# W0812 13:23:37.755673 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).encoder.layer-1.bias
# W0812 13:23:37.755718 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).encoder.layer-2.kernel
# W0812 13:23:37.755763 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).encoder.layer-2.bias
# W0812 13:23:37.755808 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).preprocessor.layer-0.kernel
# W0812 13:23:37.755852 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).preprocessor.layer-0.bias
# W0812 13:23:37.755898 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).preprocessor.layer-1.kernel
# W0812 13:23:37.755943 140258539853696 util.py:144] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).preprocessor.layer-1.bias
# W0812 13:23:37.755994 140258539853696 util.py:152] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.

# %%
# !ls -la $OUTPUTS_DIR/generated_data
# Out:
# total 203192
# drwxr-xr-x 2 root root      4096 Aug 12 13:23 .
# drwxr-xr-x 4 root root      4096 Aug 12 13:22 ..
# -rw-r--r-- 1 root root     49661 Aug 12 13:23 hmnist_reconstruction.pdf
# -rw-r--r-- 1 root root 156800128 Aug 12 13:23 imputed_no_gt.npy
# -rw-r--r-- 1 root root  51200128 Aug 12 13:23 z_mean.npy

# %%
# Copy trained models back to drive
# !cp -R $OUTPUTS_DIR/generated_data $DRIVE_OUTPUTS_DIR/generated_data
# !ls -la $DRIVE_OUTPUTS_DIR/generated_data
# Out:
# total 203175
# -rw------- 1 root root     49661 Aug 12 13:24 hmnist_reconstruction.pdf
# -rw------- 1 root root 156800128 Aug 12 13:24 imputed_no_gt.npy
# -rw------- 1 root root  51200128 Aug 12 13:24 z_mean.npy
